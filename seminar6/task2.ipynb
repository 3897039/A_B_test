# %% [markdown]
# Наша продуктовая команда в ecommerce магазине планирует запустить тест,
# направленный на ускорение загрузки сайта. Одна из основных метрик bounce rate в GA = 40%.
# Мы предполагаем, что при оптимизации сайта она изменится минимум на 20%.
# Средний трафик 4000 человек в день. Посчитайте сколько нам нужно дней держать эксперимент при alpha = 5% и beta = 20%

# %% [markdown]
# Одна из основных метрик bounce rate в GA после оптимизации будет равна 40*0.8 = 32%.
# посчитав на калкуляторе приходим к выводу, что для эксперимента нужно 1 день.
